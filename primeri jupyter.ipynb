# %% [markdown]
# #заголовок первого уровня
# ##Заголовок второго уровня
#
# **полужинрый текст** *курсив* `код в строке`
#
# Список:
# - Пункт 1
# - Пункт 2
# - Пункт 3
#
# формула: $y=mx+b$

# %% [markdown]
# %timeit sum(range(1000))

# %%
# %timeit sum(range(1000))
# Out:
# 12.6 μs ± 96.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%time
total=0
for i in range(10**6):
    total+=1
# Out:
# CPU times: total: 0 ns
# Wall time: 77.7 ms

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0, 10, 100)
y=np.sin(x)
plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("График синусоиды")
plt.show()
